# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#初始化" data-toc-modified-id="初始化-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>初始化</a></span></li><li><span><a href="#机组状态" data-toc-modified-id="机组状态-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>机组状态</a></span></li><li><span><a href="#叶根1" data-toc-modified-id="叶根1-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>叶根1</a></span></li><li><span><a href="#叶根2" data-toc-modified-id="叶根2-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>叶根2</a></span></li><li><span><a href="#叶根3" data-toc-modified-id="叶根3-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>叶根3</a></span></li><li><span><a href="#静止轮毂" data-toc-modified-id="静止轮毂-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>静止轮毂</a></span></li><li><span><a href="#旋转轮毂" data-toc-modified-id="旋转轮毂-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>旋转轮毂</a></span></li><li><span><a href="#塔底" data-toc-modified-id="塔底-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>塔底</a></span></li><li><span><a href="#塔顶" data-toc-modified-id="塔顶-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>塔顶</a></span></li><li><span><a href="#机组状态[%]" data-toc-modified-id="机组状态[%]-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>机组状态[%]</a></span></li><li><span><a href="#叶根1[%]" data-toc-modified-id="叶根1[%]-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>叶根1[%]</a></span></li><li><span><a href="#叶根2[%]" data-toc-modified-id="叶根2[%]-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>叶根2[%]</a></span></li><li><span><a href="#叶根3[%]" data-toc-modified-id="叶根3[%]-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>叶根3[%]</a></span></li><li><span><a href="#静止轮毂[%]" data-toc-modified-id="静止轮毂[%]-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>静止轮毂[%]</a></span></li><li><span><a href="#旋转轮毂[%]" data-toc-modified-id="旋转轮毂[%]-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>旋转轮毂[%]</a></span></li><li><span><a href="#塔底[%]" data-toc-modified-id="塔底[%]-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>塔底[%]</a></span></li><li><span><a href="#塔顶[%]" data-toc-modified-id="塔顶[%]-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>塔顶[%]</a></span></li></ul></div>

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di
di.display_html(
    '<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>',
    raw=True)
CSS = """#notebook div.output_subarea {max-width:100%;}"""  # changes output_subarea width to 100% (from 100% - 14ex)
HTML('<style>{}</style>'.format(CSS))
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <style>#notebook div.output_subarea {max-width:100%;}</style>

# %% [markdown]
# # 初始化

# %%
import bladed_api as b_api
import pandas as pd
import math
# import imp
# imp.reload(b_api)

# %%
DLCs=['DLC12']

# %%
path_png = r'Z:\fangyufeng\Goldflex\GW155-4500\Loads_v4.0.0HY\fatigue\res_Bladed_4_7_vs_v4.0.0'
path_xls1 = r'Z:\fangyufeng\GW155_4500_goldflex_comp_71_81_201972590727\loads\fatigue'
path_xls2 = r'Z:\fangyufeng\Goldflex\GW155-4500\Loads_v4.0.0HY\fatigue'
label1 = 'Bladed 4.7'
label2 = 'Goldflex v4.0.0'

# %% [markdown]
# # 机组状态

# %%
var_name1 = ['Mean_pitch_angle', 'Rotor_speed', 'Electrical_power']
var_name2 = ['Pi1', 'Omega', 'P']
scale_s = [math.pi / 180, math.pi / 30, 1000]
y_label_s = ['[deg]', '[rpm]', '[kW]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Mean_pitch_angle
# Rotor_speed
# Electrical_power

# %% [markdown]
# # 叶根1

# %%
var_name1 = ['Blade_root_1_Mx', 'Blade_root_1_My', 'Blade_root_1_Mz']
var_name2 = ['MxB1', 'MyB1', 'MzB1']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_1_Mx
# Blade_root_1_My
# Blade_root_1_Mz

# %% [markdown]
# # 叶根2

# %%
var_name1 = ['Blade_root_2_Mx', 'Blade_root_2_My', 'Blade_root_2_Mz']
var_name2 = ['MxB2', 'MyB2', 'MzB2']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_2_Mx
# Blade_root_2_My
# Blade_root_2_Mz

# %% [markdown]
# # 叶根3

# %%
var_name1 = ['Blade_root_3_Mx', 'Blade_root_3_My', 'Blade_root_3_Mz']
var_name2 = ['MxB3', 'MyB3', 'MzB3']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_3_Mx
# Blade_root_3_My
# Blade_root_3_Mz

# %% [markdown]
# # 静止轮毂

# %%
var_name1 = ['Stationary_hub_Mx', 'Stationary_hub_My', 'Stationary_hub_Mz']
var_name2 = ['MxNhub', 'MyNhub', 'MzNhub']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Stationary_hub_Mx
# Stationary_hub_My
# Stationary_hub_Mz

# %% [markdown]
# # 旋转轮毂

# %%
var_name1 = ['Rotating_hub_Mx', 'Rotating_hub_My', 'Rotating_hub_Mz']
var_name2 = ['MxR1', 'MyR1', 'MzR1']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Rotating_hub_Mx
# Rotating_hub_My
# Rotating_hub_Mz

# %% [markdown]
# # 塔底

# %%
var_name1 = ['MXT_0.65', 'MYT_0.65', 'MZT_0.65']
var_name2 = ['MxTb', 'MyTb', 'MzTb']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# MXT_0.65
# MYT_0.65
# MZT_0.65

# %% [markdown]
# # 塔顶

# %%
var_name1 = ['Yaw_bearing_Mx', 'Yaw_bearing_My', 'Yaw_bearing_Mz']
var_name2 = ['MxK2', 'MyK2', 'MzK2']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Yaw_bearing_Mx
# Yaw_bearing_My
# Yaw_bearing_Mz

# %% [markdown]
# # 机组状态[%]

# %%
var_name1 = ['Mean_pitch_angle', 'Rotor_speed', 'Electrical_power']
var_name2 = ['Pi1', 'Omega', 'P']
scale_s = [math.pi / 180, math.pi / 30, 1000]
y_label_s = ['[deg]', '[rpm]', '[kW]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Mean_pitch_angle
#     Mean_pitch_angle_max_min_Bladed 4.7  Pi1_max_min_Goldflex v4.0.0  \
# 0                                 30.87                        32.90
# 1                                 30.83                        32.52
# 2                                 30.21                        31.67
# 3                                 30.12                        31.57
# 4                                 29.94                        31.22
# 5                                 29.67                        31.16
# 6                                 28.74                        30.10
# 7                                 28.28                        29.18
# 8                                  0.47                         0.41
# 9                                  0.47                         0.41
# 10                                 0.47                         0.41
# 11                                 0.48                         0.41
# ...

# %% [markdown]
# # 叶根1[%]

# %%
var_name1 = ['Blade_root_1_Mx', 'Blade_root_1_My', 'Blade_root_1_Mz']
var_name2 = ['MxB1', 'MyB1', 'MzB1']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_1_Mx
#     Blade_root_1_Mx_max_min_Bladed 4.7  MxB1_max_min_Goldflex v4.0.0  \
# 0                             12830.30                      10668.62
# 1                             11613.10                      10656.68
# 2                             10653.40                      10286.97
# 3                             10637.40                       9828.55
# 4                             10621.80                       9773.03
# 5                             10548.00                       9606.85
# 6                             10409.90                       9605.07
# 7                             10154.90                       9506.50
# 8                             -8927.96                      -7669.03
# 9                             -8531.10                      -7264.83
# 10                            -7495.96                      -6707.09
# 11                            -7207.33                      -6685.77
# ...

# %% [markdown]
# # 叶根2[%]

# %%
var_name1 = ['Blade_root_2_Mx', 'Blade_root_2_My', 'Blade_root_2_Mz']
var_name2 = ['MxB2', 'MyB2', 'MzB2']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_2_Mx
#     Blade_root_2_Mx_max_min_Bladed 4.7  MxB2_max_min_Goldflex v4.0.0  \
# 0                             12029.10                      10197.36
# 1                             11825.20                      10154.41
# 2                             11656.40                       9761.99
# 3                             11053.30                       9750.74
# 4                             10946.10                       9716.38
# 5                             10783.60                       9316.19
# 6                             10528.60                       9251.04
# 7                             10242.50                       9075.05
# 8                             -8619.58                      -7807.62
# 9                             -8366.93                      -7440.77
# 10                            -8178.54                      -7393.84
# 11                            -7739.47                      -6605.40
# ...

# %% [markdown]
# # 叶根3[%]

# %%
var_name1 = ['Blade_root_3_Mx', 'Blade_root_3_My', 'Blade_root_3_Mz']
var_name2 = ['MxB3', 'MyB3', 'MzB3']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Blade_root_3_Mx
#     Blade_root_3_Mx_max_min_Bladed 4.7  MxB3_max_min_Goldflex v4.0.0  \
# 0                             11896.30                      10360.27
# 1                             11132.30                      10102.10
# 2                             11118.70                       9947.74
# 3                             10918.40                       9843.58
# 4                             10442.50                       9809.48
# 5                             10251.60                       9725.94
# 6                             10208.30                       9673.65
# 7                             10154.40                       9664.36
# 8                             -7537.19                      -6920.61
# 9                             -7407.15                      -6851.46
# 10                            -7106.20                      -6838.78
# 11                            -6995.24                      -6280.34
# ...

# %% [markdown]
# # 静止轮毂[%]

# %%
var_name1 = ['Stationary_hub_Mx', 'Stationary_hub_My', 'Stationary_hub_Mz']
var_name2 = ['MxNhub', 'MyNhub', 'MzNhub']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Stationary_hub_Mx
#     MxNhub_max_min_Goldflex v4.0.0  Stationary_hub_Mx_max_min_Bladed 4.7  \
# 0                          5136.72                               5196.01
# 1                          5136.72                               5194.43
# 2                          5136.72                               5193.80
# 3                          5136.72                               5192.27
# 4                          5136.72                               5192.25
# 5                          5136.72                               5190.57
# 6                          5136.72                               5184.06
# 7                          5136.72                               5182.13
# 8                            -0.00                                 -4.93
# 9                            -0.00                                 -4.91
# 10                           -0.00                                 -4.73
# ...

# %% [markdown]
# # 旋转轮毂[%]

# %%
var_name1 = ['Rotating_hub_Mx', 'Rotating_hub_My', 'Rotating_hub_Mz']
var_name2 = ['MxR1', 'MyR1', 'MzR1']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Rotating_hub_Mx
#     MxR1_max_min_Goldflex v4.0.0  Rotating_hub_Mx_max_min_Bladed 4.7  \
# 0                        5136.72                             5196.01
# 1                        5136.72                             5194.43
# 2                        5136.72                             5193.80
# 3                        5136.72                             5192.27
# 4                        5136.72                             5192.25
# 5                        5136.72                             5190.57
# 6                        5136.72                             5184.06
# 7                        5136.72                             5182.13
# 8                          -0.00                               -4.93
# 9                          -0.00                               -4.91
# 10                         -0.00                               -4.73
# 11                          0.00                               -4.55
# ...

# %% [markdown]
# # 塔底[%]

# %%
var_name1 = ['MXT_0.65', 'MYT_0.65', 'MZT_0.65']
var_name2 = ['MxTb', 'MyTb', 'MzTb']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# MXT_0.65
#     MXT_0.65_max_min_Bladed 4.7  MxTb_max_min_Goldflex v4.0.0  \
# 0                       47062.2                      47700.40
# 1                       46236.8                      44841.12
# 2                       39970.9                      44197.08
# 3                       39787.2                      39819.02
# 4                       39357.6                      38787.38
# 5                       38347.8                      37681.70
# 6                       36957.6                      36517.87
# 7                       36776.6                      36437.17
# 8                      -22199.0                     -31756.88
# 9                      -19968.5                     -28061.66
# 10                     -19599.2                     -25736.94
# 11                     -19223.7                     -24451.57
# 12                     -18586.0                     -21768.64
# 13                     -18555.0                     -20597.71
# ...

# %% [markdown]
# # 塔顶[%]

# %%
var_name1 = ['Yaw_bearing_Mx', 'Yaw_bearing_My', 'Yaw_bearing_Mz']
var_name2 = ['MxK2', 'MyK2', 'MzK2']
scale_s = [1000, 1000, 1000]
y_label_s = ['[kNm]', '[kNm]', '[kNm]']
b_api.vs_plot_bar(DLCs, path_png, path_xls1, path_xls2, label1, label2,var_name1,var_name2,scale_s,y_label_s)
# Out:
# DLC12
# Yaw_bearing_Mx
#     MxK2_max_min_Goldflex v4.0.0  Yaw_bearing_Mx_max_min_Bladed 4.7  \
# 0                        6452.65                            6576.32
# 1                        6434.31                            6502.12
# 2                        6387.01                            6493.39
# 3                        6385.97                            6401.34
# 4                        6323.38                            6376.35
# 5                        6311.53                            6297.61
# 6                        6293.31                            6293.77
# 7                        6288.18                            6245.20
# 8                        -181.54                            -164.99
# 9                        -155.87                            -136.64
# 10                       -122.51                            -130.92
# 11                       -116.02                            -124.72
# ...
